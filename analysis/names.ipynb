# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import ujson as json
import glob as g
import random as rnd
import os.path as op
import time
import math
import numpy as np
from skimage import io, transform
import skimage.color as skc
import re

from tqdm import tqdm

import pandas as pd
import seaborn as sns

import multiprocessing
import hashlib as hl
import scipy.spatial.distance as sd

import subprocess
import editdistance as ed
import itertools as it
import functools as ft

# %%
names = pd.read_csv('/media/jakob/bigdata/train/gnd_export/Person.csv')
len(names)
# Out:
# 134538

# %%
# !wc /media/jakob/bigdata/train/gnd_export/Person.csv
# Out:
#  134539  165252 2387127 /media/jakob/bigdata/train/gnd_export/Person.csv

# %%
sorted(set(names['surname']))
# Out:
# ["A'Beckett",
#  'Aa',
#  'Aachen',
#  'Aaltonen',
#  'Aavik',
#  'Abbatini',
#  'Abbing',
#  'Abbott',
#  'Abdel-Rahim',
#  'Abe',
#  'Abeille',
#  'Abel',
#  'Abeles',
#  'Abendroth',
#  'Abert',
#  'Ablinger',
#  'Abraham',
#  'Abrahamowicz',
#  'Abrahamsen',
#  'Abrahamyan',
#  'Abrams',
#  'Absil',
#  'Abt',
#  'Accolay',
#  'Achleitner',
#  'Achron',
#  'Achs',
#  'Acker',
#  'Ackermann',
#  'Ackermans',
#  'Acquavella',
#  'Actor',
#  'Acun\xcc\x83a',
#  'Ada',
#  'Adai\xcc\x88ewsky',
#  'Adam',
#  'Adami',
#  'Adamic\xcc\x8c',
#  'Adamis',
#  'Adamo',
#  'Adams',
#  'Ada\xcc\x80n',
#  'Ada\xcc\x81mek',
#  'Addinsell',
#  'Addison',
#  'Adelburg',
#  'Adenberg',
#  'Ade\xcc\x80s',
#  'Adler',
#  'Adlgasser',
#  'Adolf',
#  'Adolphe',
#  'Adorno',
#  'Adriaenssen',
#  'Adson',
#  'Advis',
#  'Aeschbacher',
#  'Afanas\xca\xb9ev',
#  'Afifi',
#  'Agafonnikov',
#  'Agazzari',
#  'Ager',
#  'Aggha\xcc\x81zy',
#  'Agnesens',
#  'Agnesi',
#  'Agobet',
#  'Agopov',
#  'Agostini',
#  'Agrell',
#  'Agricola',
#  'Agsteribbe',
#  'Agthe',
#  'Aguado y Garci\xcc\x81a',
#  'Agudelo',
#  'Aguiar',
#  'Aguila',
#  'Aguilar',
#  'Aguilera',
#  'Aguilera de Heredia',
#  'Aguirre',
#  'Aharoni',
#  'Aharonia\xcc\x81n',
#  'Ahle',
#  'Ahlert',
#  'Ahne',
#  'Aho',
#  'Ahrens',
#  'Aiblinger',
#  'Aich',
#  'Aichelbourg',
#  'Aichelburg',
#  'Aichinger',
#  'Aigmu\xcc\x88ller',
#  'Aigner',
#  'Aimon',
#  'Aitken',
#  'Ajax',
#  'Akiyoshi',
#  'Akpinar',
#  'Akses',
#  'Akutagawa',
#  'Akymenko',
#  'Akyol',
#  'Al-Odeh',
#  'Alai',
#  'Alain',
#  'Alard',
#  'Alary',
#  'Alas',
#  'Albanese',
#  'Albarn',
#  'Alberstoetter',
#  'Albert',
#  'Alberth',
#  'Alberti',
#  'Albertini',
#  'Albertsen',
#  'Albes',
#  'Albe\xcc\x81niz',
#  'Albicastro',
#  'Albinoni',
#  'Alborea',
#  'Albrecht',
#  'Albrechtsberger',
#  'Albrici',
#  'Albright',
#  'Alcalay',
#  'Alca\xcc\x81ntara',
#  'Alca\xcc\x81zar',
#  'Alcock',
#  'Alder',
#  'Aldridge',
#  'Aldrovandini',
#  'Aleksandrov',
#  'Aleksandrova-Koc\xcc\x8cetova',
#  'Alemann',
#  'Alencar',
#  'Aleotti',
#  'Ales',
#  'Alessandrini',
#  'Alessandro',
#  'Aletter',
#  'Alexander',
#  'Alexandra',
#  'Alfano',
#  'Alford',
#  'Alfve\xcc\x81n',
#  'Algarotti',
#  'Alguero\xcc\x81',
#  'Ali-Sade',
#  'Alison',
#  "Aljab'ev",
#  'Alkan',
#  'Allegri',
#  'Allen',
#  'Allende Saro\xcc\x81n',
#  'Allende-Blin',
#  'Allers',
#  'Alm',
#  'Almashi',
#  'Almeida',
#  'Almenra\xcc\x88der',
#  'Almeyda',
#  'Aloiz',
#  'Alpaerts',
#  'Alpher',
#  'Alschausky',
#  'Alsina',
#  'Altan',
#  'Altenburg',
#  'Alte\xcc\x80s',
#  'Altmann',
#  'Altnikol',
#  'Altschuler',
#  'Altwein',
#  'Alvarez',
#  'Alvear',
#  'Alwyn',
#  'Amacher',
#  'Amadei',
#  'Amandi',
#  'Amani',
#  'Amann',
#  'Amano',
#  'Amanti',
#  'Amberg',
#  'Ambleville',
#  'Ambros',
#  'Ambrosch',
#  'Ambrosio',
#  'Ambrosius',
#  'Amdahl',
#  'Ameele',
#  'Amend',
#  'Amendola',
#  'Amirkhanian',
#  'Amlin',
#  'Ammann',
#  'Ammende',
#  'Ammerbach',
#  'Amner',
#  'Amon',
#  'Amoroso',
#  'Amos',
#  'Amram',
#  'Amy',
#  'An',
#  'Anacker',
#  'Anastassiou',
#  'Anchieta',
#  'Ander',
#  'Anders',
#  'Anders-Strehmel',
#  'Andersen',
#  'Anderson',
#  'Andersson',
#  'Andes',
#  'Andre',
#  'Andreae',
#  'Andreas',
#  'Andres',
#  'Andress',
#  'Andrews',
#  'Andre\xcc\x80s',
#  'Andre\xcc\x81',
#  'Andre\xcc\x81e',
#  'Andrich',
#  'Andricu',
#  'Andriessen',
#  'Androsch',
#  'Andrus\xcc\x8cko',
#  'Anerio',
#  'Anet',
#  'Anfossi',
#  'Angelini Bontempi',
#  'Angelis',
#  'Angelis-Valentini',
#  'Anger',
#  'Angerer',
#  'Angermann',
#  'Anghel',
#  'Anghelescu',
#  'Anglebert',
#  'Angleria',
#  'Angst',
#  'Angstenberger',
#  'Angulo',
#  'Anhalt',
#  'Anido',
#  'Animuccia',
#  'Anka',
#  'Ansink',
#  'Ansorge',
#  'Anstatt',
#  'Ant',
#  'Antalffy-Zsi\xcc\x81ross',
#  'Antegnati',
#  'Antesberger',
#  'Antheil',
#  'Antico',
#  'Antipov',
#  'Antognini',
#  'Antoine',
#  'Anton',
#  'Antonacci',
#  'Antonelli',
#  'Antoni',
#  'Antonii',
#  'Antonini',
#  'Antoniotto',
#  'Antoniou',
#  'Antweiler',
#  'Anunciac\xcc\xa7a\xcc\x83o',
#  'Anzaghi',
#  'Anzoletti',
#  'Aperghis',
#  'Apolinarski',
#  'Apolloni',
#  'Apostel',
#  'App',
#  'Appel',
#  'Appermont',
#  'Applebaum',
#  'Aracil',
#  'Arad',
#  'Araja',
#  'Arapov',
#  'Araujo',
#  'Ara\xcc\x81mbarri y Ga\xcc\x81rate',
#  'Ara\xcc\x81nyi',
#  'Arban',
#  'Arbatsky',
#  'Arbo\xcc\x81s',
#  'Arcadelt',
#  'Arce',
#  'Arch',
#  'Archangel\xca\xb9skij',
#  'Archer',
#  'Archimbaud',
#  'Ardelt',
#  'Arden',
#  'Arditi',
#  'Arditto',
#  'Arel',
#  'Arend',
#  'Arends',
#  'Arenskij',
#  'Arenson',
#  'Arfib',
#  'Arfken',
#  'Argast',
#  'Argento',
#  'Ariosti',
#  'Ariva',
#  'Arkwright',
#  'Arlen',
#  'Arma',
#  'Arman',
#  'Armbruester',
#  'Armbrust',
#  'Armer',
#  'Armsdorff',
#  'Armstrong',
#  'Arnaudov',
#  'Arnauld',
#  'Arne',
#  'Arnecke',
#  'Arnell',
#  'Arnfelser',
#  'Arnic\xcc\x8c',
#  'Arnim',
#  'Arnold',
#  'Arolas',
#  'Arp',
#  'Arriaga',
#  'Arrieu',
#  'Arrigo',
#  'Arro',
#  'Arteaga',
#  'Arter',
#  'Arte\xcd\x8f\xcc\x88mov',
#  'Arthuys',
#  'Arto\xcc\x82t',
#  'Artusi',
#  'Artusini',
#  'Arutjunjan',
#  'Arutjunova',
#  'Arzoumanov',
#  'Ascencio',
#  'Aschauer',
#  'Aschenbach',
#  'Aschenbrenner',
#  'Ascher',
#  'Aschner',
#  'Asencio',
#  'Asheim',
#  'Ashelm',
#  'Ashley',
#  'Ashmore',
#  'Ashton',
#  'Asia',
#  'Asioli',
#  'Askill',
#  'Askin',
#  'Asma',
#  'Asmus',
#  'Asmussen',
#  'Asola',
#  'Asriel',
#  'Assad',
#  'Assandra',
#  'Assies',
#  'Assmayer',
#  'Aster',
#  'Astfalk',
#  'Astorga',
#  'Atilano',
#  'Attaingnant',
#  'Atterberg',
#  'Attey',
#  'Attwood',
#  'Auber',
#  'Aubert',
#  'Aubin',
#  'Auclert',
#  'Audersch',
#  'Audinovski',
#  'Audran',
#  'Auenmu\xcc\x88ller',
#  'Auerbach',
#  'Aufenanger',
#  'Auffmann',
#  'Aufray',
#  'Aufschnaiter',
#  'Augst',
#  'Augustin',
#  'Aulin',
#  'Aulio',
#  'Aumann',
#  'Auric',
#  'Aurnhammer',
#  'Austin',
#  'Autenrieth',
#  'Autenrieth-Schleussner',
#  'Avenarius',
#  'Averkamp',
#  'Avesson',
#  'Avidom',
#  'Avison',
#  'Avitrano',
#  'Avni',
#  'Avon',
#  'Avondano',
#  'Avramovski',
#  'Axelrod',
#  'Axman',
#  'Axton',
#  'Ayres',
#  'Ayton',
#  'Azevedo de Silva',
#  'A\xcc\x81cs',
#  'A\xcc\x88bel',
#  'Baake',
#  'Baal',
#  'Baaren',
#  'Babaj\xcc\x8canyan',
#  'Babbitt',
#  'Babcock',
#  'Babell',
#  'Babin',
#  'Bacalov',
#  'Bacarisse',
#  'Bacciarelli',
#  'Baccusi',
#  'Bacevic\xcc\x8cius',
#  'Bacewicz',
#  'Bach',
#  'Bacharach',
#  'Bacheler',
#  'Bachelet',
#  'Bachmann',
#  'Bachner',
#  'Bachofen',
#  'Bachor',
#  'Bachrich',
#  'Bachschmid',
#  'Bacilieri',
#  'Bacilly',
#  'Backer-Gr\xc3\xb8ndahl',
#  'Backhausen',
#  'Backofen',
#  'Bacri',
#  'Badalla',
#  'Baden',
#  'Badent',
#  'Badings',
#  'Badinski',
#  'Badura-Skoda',
#  'Baecker',
#  'Baer',
#  'Baeyens',
#  'Bagdasaryan',
#  'Bagdonas',
#  'Bagge',
#  'Baggioli',
#  'Bagley',
#  'Baguer',
#  'Bag\xcc\x87dasaryan',
#  'Bahr',
#  'Bai',
#  'Baier',
#  'Bailey',
#  'Baillot',
#  'Bainbridge',
#  'Bainton',
#  'Baird',
#  'Bairstow',
#  'Bajamonti',
#  'Bajoras',
#  'Bak',
#  'Bakalejnikov',
#  'Baker',
#  'Bakfark',
#  'Bakker',
#  'Baks\xcc\x8ci',
#  'Balada',
#  'Balakauskas',
#  'Balakirev',
#  'Balanya\xcc\x80',
#  'Balassa',
#  'Balay',
#  'Bala\xcc\x81zs',
#  'Balbastre',
#  'Balbi',
#  'Baldano',
#  'Baldassari',
#  'Balducci',
#  'Balena',
#  'Balestracci',
#  'Balfe',
#  'Balissat',
#  'Balkanski',
#  'Ball',
#  'Ballard',
#  'Ballata',
#  'Balletti',
#  'Ballif',
#  'Ballis',
#  'Balmer',
#  'Balsamino',
#  'Baltakas',
#  'Baltin',
#  'Balvin',
#  'Balzanelli',
#  'Bamba',
#  'Bamer',
#  'Bamert',
#  'Bammer',
#  'Banasik',
#  'Banchieri',
#  'Banci',
#  'Banck',
#  'Banco',
#  'Bancquart',
#  'Bandini',
#  'Bandolim',
#  'Bane\xcc\x80s',
#  'Banfield',
#  'Banholzer',
#  'Banks',
#  'Bannasch',
#  'Banner',
#  'Banning',
#  'Bans\xcc\x8cc\xcc\x8cikov',
#  'Bantelmann',
#  'Banter',
#  'Bantock',
#  'Bantzer',
#  'Baptist',
#  'Barabas',
#  'Barabasch',
#  'Barath',
#  'Barati',
#  'Barbarino',
#  'Barbe',
#  'Barbella',
#  'Barber',
#  'Barberiis',
#  'Barbetta',
#  'Barbici',
#  'Barbier',
#  'Barbieri',
#  'Barbireau',
#  'Barbirolli',
#  'Barblan',
#  'Barboteu',
#  'Barcaba',
#  'Barce',
#  'Barchet',
#  'Barchewitz',
#  'Barcos',
#  'Bardanashvili',
#  'Barden',
#  'Bardo\xcc\x81s',
#  'Bares',
#  'Barfoed',
#  'Bargheer',
#  'Bargiel',
#  'Bargielski',
#  'Bargnani',
#  'Barie\xcc\x81',
#  'Bark',
#  'Barkauskas',
#  'Barlow',
#  'Barmeyer',
#  'Barmotin',
#  'Barnby',
#  'Barner',
#  'Barnett',
#  'Barolsky',
#  'Baron',
#  'Baroni',
#  'Baroni-Cavalcabo\xcc\x80',
#  'Barotek',
#  'Barraine',
#  'Barraque\xcc\x81',
#  'Barratt',
#  'Barraud',
#  'Barrera',
#  'Barrett',
#  'Barrientos Elvir',
#  'Barrios Mangore\xcc\x81',
#  'Barro',
#  'Barron',
#  'Barroso',
#  'Barry',
#  'Barsanti',
#  'Barsva\xcc\x81ri',
#  'Bart',
#  'Bartay',
#  'Bartei',
#  'Bartel',
#  'Bartesch',
#  'Bartetzki',
#  'Barth',
#  'Barthel',
#  'Barthelmes',
#  'Barthe\xcc\x81lemon',
#  'Barthmes',
#  'Bartholemy',
#  'Bartlet',
#  'Bartling',
#  'Bartmann',
#  'Bartmuss',
#  'Bartolini',
#  'Bartoloni',
#  'Bartolucci',
#  'Barton-Armstrong',
#  'Barton\xcc\x8c',
#  'Bartos',
#  'Bartosch',
#  'Bartos\xcc\x8c',
#  'Bartow',
#  'Barto\xcc\x81k',
#  'Bartsch',
#  'Bartulis',
#  'Barwig',
#  'Barz',
#  'Bas',
#  'Basha',
#  'Bashaw',
#  'Basili',
#  'Basler',
#  'Bass',
#  'Bassani',
#  'Bassano',
#  'Bassett',
#  'Bassi',
#  'Bastiaans',
#  'Bastian',
#  'Baston',
#  'Bas\xcc\xa7eg\xcc\x86mezler',
#  'Batchelar',
#  'Bates',
#  'Bateson',
#  'Batik',
#  'Batiste',
#  'Batt',
#  'Battanchon',
#  'Battiato',
#  'Battioli',
#  'Battishill',
#  'Battistelli',
#  'Battisti',
#  'Battke',
#  'Battmann',
#  'Bauckholt',
#  'Baudrexel',
#  'Baudringer',
#  'Bauer',
#  'Bauersachs',
#  'Bauerschmidt',
#  'Bauldeweyn',
#  'Baum',
#  'Baumann',
#  'Baumbach',
#  'Baumeister',
#  'Baumert',
#  'Baumfelder',
#  'Baumgarten',
#  'Baumgartl',
#  'Baumgartner',
#  'Baur',
#  'Bausznern',
#  'Bauzin',
#  'Bau\xc3\x9fnern',
#  'Bavdek',
#  'Bawr',
#  'Bax',
#  'Bay',
#  'Bayer',
#  'Bayern',
#  'Bayle',
#  'Baynov',
#  'Baza\xcc\x81n',
#  'Bazil',
#  'Bazzini',
#  'Ba\xcc\x81rta',
#  'Ba\xcc\x82ton',
#  'Ba\xcc\x88ck',
#  'Ba\xcc\x88cker',
#  'Ba\xcc\x88hr',
#  'Ba\xcc\x88r',
#  'Ba\xcc\x88renz',
#  'Ba\xcc\x88rmann',
#  'Ba\xcc\x88rtsch',
#  'Ba\xcc\x88rtschi',
#  'Ba\xcc\x88ss',
#  'Ba\xcc\x88umer',
#  'Ba\xcc\x88umle',
#  'Ba\xcc\xa8darzewska-Baranowska',
#  'Beach',
#  'Beamish',
#  'Beaser',
#  'Beat',
#  'Beaucourt',
#  'Beaudoin',
#  'Beauvarlet-Charpentier',
#  'Bebelaar',
#  'Becce',
#  'Becerra-Schmidt',
#  'Bechert',
#  'Bechtel',
#  'Beck',
#  'Beck-Larsen',
#  'Beckemeier',
#  'Becker',
#  'Beckerath',
#  'Beckers',
#  'Beckett',
#  'Beckmann',
#  'Beckscha\xcc\x88fer',
#  'Beckwith',
#  'Becucci',
#  'Bec\xcc\x8cvar\xcc\x8covsky\xcc\x81',
#  'Beddig',
#  'Bedford',
#  'Bednall',
#  'Bednarik',
#  'Bedrossian',
#  'Bedruna',
#  'Bedyngham',
#  'Beecham',
#  'Beeck',
#  'Beecke',
#  'Beecroft',
#  'Beeferman',
#  'Beekum',
#  'Beele',
#  'Beer',
#  'Beer-Demander',
#  'Beer-Walbrunn',
#  'Beerhalter',
#  'Beeson',
#  'Beethoven',
#  'Beetz',
#  'Beez',
#  'Beffa',
#  'Begaliev',
#  'Beglarian',
#  'Behle',
#  'Behles',
#  'Behner',
#  'Behnke',
#  'Behr',
#  'Behrend',
#  'Behrends',
#  'Behrman',
#  'Beil',
#  'Beilharz',
#  'Beimel',
#  'Beinke',
#  'Belamaric\xcc\x81',
#  'Belbl',
#  'Belcke',
#  'Belin',
#  'Beljon',
#  'Bell',
#  'Bella',
#  'Bellanda',
#  'Bellazzo',
#  'Bellermann',
#  'Belli',
#  'Bellinati',
#  'Bellini',
#  'Bellinzani',
#  'Bellisario',
#  'Bellman',
#  'Belloli',
#  'Belos\xcc\x8cickij',
#  'Beltrami',
#  'Belzer',
#  'Bemberg',
#  'Bembinow',
#  'Bembo',
#  'Ben-H\xcc\xa3ayyi\xcc\x82m',
#  'Benary',
#  'Benati',
#  'Benatzky',
#  'Benaut',
#  'Bencini',
#  'Benda',
#  'Bendel',
#  'Bender',
#  'Benditskiy',
#  'Bendix',
#  'Bendl',
#  'Bendusi',
#  'Benedetti',
#  'Benedict',
#  'Benejam',
#  'Beneken',
#  'Benes\xcc\x8c',
#  'Benevoli',
#  'Bengraf',
#  'Benguerel',
#  'Benincori',
#  'Benizelos',
#  'Benjamin',
#  'Benker',
#  'Benn',
#  'Bennet',
#  'Bennett',
#  'Benninghoff',
#  'Benoist',
#  'Benoi\xcc\x82t',
#  'Benovic',
#  'Bense',
#  'Benserade',
#  'Benshoof',
#  'Bensmann',
#  'Benson',
#  'Bentoiu',
#  'Bentzon',
#  'Benvenuto',
#  'Benz',
#  'Benzon',
#  'Beppe',
#  'Beraldo',
#  'Beran',
#  'Berardi',
#  'Berauer',
#  'Berberian',
#  'Berbiguier',
#  'Berchem',
#  'Berens',
#  'Berenwenger',
#  'Beretta',
#  'Beretti',
#  "Berezovs'kyj",
#  'Berg',
#  'Bergamo',
#  'Berge',
#  'Bergen',
#  'Berger',
#  'Bergh',
#  'Berghaus',
#  'Berghorn',
#  'Bergman',
#  'Bergmann',
#  'Bergsma',
#  'Bergson',
#  'Bergt',
#  'Berinskij',
#  'Berio',
#  'Berkeley',
#  'Berking',
#  'Berlin',
#  'Berlinski',
#  'Berlioz',
#  'Berman',
#  'Bermbach',
#  'Bermel',
#  'Bermudo',
#  'Bernabei',
#  'Bernard',
#  'Bernardi',
#  'Bernardini',
#  'Bernau',
#  'Bernaud',
#  'Berners',
#  'Bernert',
#  'Bernhard',
#  'Bernier',
#  'Bernsmeister',
#  'Bernstein',
#  'Berntsen Aas',
#  'Berr',
#  'Berry',
#  'Bersa',
#  'Bertali',
#  'Bertalotti',
#  'Berteau',
#  'Bertelsmeier',
#  'Berte\xcc\x81',
#  'Bertheaume',
#  'Berthold-Lindner',
#  'Berthomieu',
#  'Bertin',
#  'Bertini',
#  'Bertoldo',
#  'Berton',
#  'Bertoncini',
#  'Bertoni',
#  'Berto\xcc\x81k',
#  'Bertram',
#  'Bertrand',
#  'Bertuletti',
#  'Berwald',
#  'Besard',
#  'Besch',
#  'Besozzi',
#  'Bessell',
#  'Besser',
#  'Best',
#  'Besta\xcc\x88ndig',
#  'Bethke',
#  'Bethmann',
#  'Betscher',
#  'Betta',
#  'Bettendorf',
#  'Bettinelli',
#  'Betz',
#  'Betzler',
#  'Beuerle',
#  'Beuger',
#  'Beugniot',
#  'Beurden',
#  'Beurle',
#  'Beutler',
#  'Bevan',
#  'Beville',
#  'Bevin',
#  'Beyer',
#  'Beytelmann',
#  'Beythien',
#  'Bezde\xcc\x8ck',
#  'Bezler',
#  'Bezold',
#  'Bezpalcova\xcc\x81',
#  'Be\xcc\x81caud',
#  'Be\xcc\x81dard',
#  'Be\xcc\x81lier',
#  'Be\xcc\x81ranger',
#  'Be\xcc\x81rat',
#  'Be\xcc\x81res\xcc\x8c',
#  'Be\xcc\x81riot',
#  'Be\xcc\x81rtola',
#  'Biagi',
#  'Bial',
#  'Bialas',
#  'Bianchera',
#  'Bianchi',
#  'Bianchini',
#  'Bianciardi',
#  'Bianco',
#  'Bibalo',
#  'Biber',
#  'Biber von Bibern',
#  'Bibergan',
#  'Bibl',
#  'Bibyk',
#  'Bicat',
#  'Bidgood',
#  'Biebl',
#  'Biechteler',
#  'Biedermann',
#  'Biedrzycki',
#  'Biehl',
#  'Biel',
#  'Bielawa',
#  'Bieler',
#  'Bieler-Wendt',
#  'Bieling',
#  'Biener',
#  'Bienwald',
#  'Biersack',
#  'Bierwald',
#  'Bietz',
#  'Bigaglia',
#  'Bigelow',
#  'Biggs',
#  'Bigot',
#  'Bihari',
#  'Bikkembergs',
#  'Bilk',
#  'Bill',
#  'Biller',
#  'Billings',
#  'Billone',
#  'Bilse',
#  'Bimberg',
#  'Binchois',
#  'Binder',
#  'Binet',
#  'Binge',
#  'Bingham',
#  'Binic\xcc\x8cki',
#  'Binkerd',
#  'Birch',
#  'Birck',
#  'Birckenstock',
#  'Bird',
#  'Birk',
#  'Birkenko\xcc\x88tter',
#  'Birn',
#  'Birnbach',
#  'Birnbaum',
#  'Biro',
#  'Birtwistle',
#  ...]
