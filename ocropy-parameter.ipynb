# %% [markdown]
# ## Anpassung der OCR-Parameter

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import ocrolib
from ocrolib import morph, imshow
from pylab import imread
def displaysegs(f): morph.showlabels(ocrolib.read_line_segmentation(f))
from glob import glob
from IPython.display import display, Image

# %%
from IPython.display import Image
Image(filename='../catalog-testset/SD00200000205.png')

# %%
# !ocropus-nlbin -t 0.5 -z 1.0 ../catalog-testset/SD/SD00200000528.png
display(Image(filename='../catalog-testset/SD/SD00200000528.bin.png'))
# Out:
# INFO:  #../catalog-testset/SD/SD00200000528.png
# INFO:  === ../catalog-testset/SD/SD00200000528.png 1
# INFO:  flattening
# INFO:  estimating skew angle
# INFO:  estimating thresholds
# INFO:  rescaling
# INFO:  ../catalog-testset/SD/SD00200000528.png lo-hi (0.73 1.11) angle  0.1
# INFO:  writing

# %%
# !ocropus-gpageseg --maxcolseps 0 --usegauss -z 1.0 ../catalog-testset/SD/SD00200000528.bin.png
display(Image(filename='../catalog-testset/SD/SD00600000350.pseg.png'))
# !ls ../catalog-testset/SD/SD00200000003/
# Out:
# INFO:
# INFO:  ########## /home/jakob/anaconda/bin/ocropus-gpageseg --maxcolseps 0 --u
# INFO:
# INFO:  ../catalog-testset/SD/SD00200000528.bin.png
# INFO:  scale 16.7332005307
# INFO:  computing segmentation
# INFO:  computing column separators
# INFO:  computing lines
# INFO:  propagating labels
# INFO:  spreading labels
# INFO:  number of lines8
# INFO:  finding reading order
# INFO:  writing lines
# INFO:       7 ../catalog-testset/SD/SD00200000528.bin.png 16.7  8
# 010001.bin.png	   010004.gt.txt      010007.txt	 01000a.txt.gt.txt
# 010001.gt.txt	   010004.txt	      010007.txt.gt.txt  01000b.bin.png
# 010001.txt	   010004.txt.gt.txt  010008.bin.png	 01000b.gt.txt
# 010001.txt.gt.txt  010005.bin.png     010008.gt.txt	 01000b.txt
# 010002.bin.png	   010005.gt.txt      010008.txt	 01000b.txt.gt.txt
# 010002.gt.txt	   010005.txt	      010008.txt.gt.txt  01000c.bin.png
# 010002.txt	   010005.txt.gt.txt  010009.bin.png	 01000c.gt.txt
# 010002.txt.gt.txt  010006.bin.png     010009.gt.txt	 01000c.txt
# 010003.bin.png	   010006.gt.txt      010009.txt	 01000c.txt.gt.txt
# 010003.gt.txt	   010006.txt	      010009.txt.gt.txt  01000d.bin.png
# 010003.txt	   010006.txt.gt.txt  01000a.bin.png
# 010003.txt.gt.txt  010007.bin.png     01000a.gt.txt
# 010004.bin.png	   010007.gt.txt      01000a.txt

# %%
# plt.figure(figsize=(12,8))

segments = glob('../catalog-testset/SD/SD00600000026/??????.bin.png')
for i, s in enumerate(segments):
#     plt.subplot(8,1,i+1)
    print s
    display(Image(filename=s))
# Out:
# ../catalog-testset/SD/SD00600000026/010005.bin.png
# ../catalog-testset/SD/SD00600000026/01000a.bin.png
# ../catalog-testset/SD/SD00600000026/010001.bin.png
# ../catalog-testset/SD/SD00600000026/010007.bin.png
# ../catalog-testset/SD/SD00600000026/01000c.bin.png
# ../catalog-testset/SD/SD00600000026/01000b.bin.png
# ../catalog-testset/SD/SD00600000026/010003.bin.png
# ../catalog-testset/SD/SD00600000026/010008.bin.png
# ../catalog-testset/SD/SD00600000026/010006.bin.png
# ../catalog-testset/SD/SD00600000026/010002.bin.png
# ../catalog-testset/SD/SD00600000026/010009.bin.png
# ../catalog-testset/SD/SD00600000026/010004.bin.png

# %%
glob('../catalog-testset/SD/SD00200000003/*')
# Out:
# ['../catalog-testset/SD/SD00200000003/01000b.txt',
#  '../catalog-testset/SD/SD00200000003/010003.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/01000c.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010005.bin.png',
#  '../catalog-testset/SD/SD00200000003/010009.txt',
#  '../catalog-testset/SD/SD00200000003/010006.txt',
#  '../catalog-testset/SD/SD00200000003/01000a.bin.png',
#  '../catalog-testset/SD/SD00200000003/010008.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/01000d.bin.png',
#  '../catalog-testset/SD/SD00200000003/010002.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010001.bin.png',
#  '../catalog-testset/SD/SD00200000003/010007.bin.png',
#  '../catalog-testset/SD/SD00200000003/01000c.bin.png',
#  '../catalog-testset/SD/SD00200000003/010003.txt',
#  '../catalog-testset/SD/SD00200000003/010008.txt',
#  '../catalog-testset/SD/SD00200000003/01000a.txt',
#  '../catalog-testset/SD/SD00200000003/010007.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010007.txt',
#  '../catalog-testset/SD/SD00200000003/01000b.bin.png',
#  '../catalog-testset/SD/SD00200000003/010001.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/01000a.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010006.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010009.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010004.txt',
#  '../catalog-testset/SD/SD00200000003/01000b.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/01000c.txt',
#  '../catalog-testset/SD/SD00200000003/010003.bin.png',
#  '../catalog-testset/SD/SD00200000003/010002.txt',
#  '../catalog-testset/SD/SD00200000003/010005.txt.gt.txt',
#  '../catalog-testset/SD/SD00200000003/010005.txt',
#  '../catalog-testset/SD/SD00200000003/010001.txt',
#  '../catalog-testset/SD/SD00200000003/010008.bin.png',
#  '../catalog-testset/SD/SD00200000003/010006.bin.png',
#  '../catalog-testset/SD/SD00200000003/010002.bin.png',
#  '../catalog-testset/SD/SD00200000003/010009.bin.png',
#  '../catalog-testset/SD/SD00200000003/010004.bin.png',
#  '../catalog-testset/SD/SD00200000003/010004.txt.gt.txt']

# %%
# ?commonprefix
origin = '../catalog-gt/SD/SD00200000245/010002.gt.txt'

prefix = commonprefix([origin, base])
target = join(target_base, origin[len(base):])
target
# Out:
# '../eval-ocr/SD/SD00200000245/010002.gt.txt'

# %%
origin
# Out:
# '../catalog-gt/SD/SD00200000245/010002.gt.txt'

# %%
from os.path import join, split, splitext,commonprefix, isdir
from os import makedirs, listdir
from glob import glob
import subprocess

def remove_ext(name):
    return name[:name.index('.')]
#  ../catalog-testset/SD/SD00200000003/*.gt.txt
def copyTo( base, target_base, pattern, id_filter=None, ext='.txt'):
    files = glob(join(base, pattern))
    print id_filter
    for f in files:
        if id_filter and not (split(split(f)[0])[1] in id_filter):
#             print split(split(f)[0])[1]
            continue
        prefix = commonprefix([f, base])
        target = join(target_base, f[len(base):])
        target = join(split(target)[0], remove_ext(split(target)[1]) + ext)
        if not isdir(split(target)[0]):
            makedirs(split(target)[0])
        p = ['cp', f, target]
        print ' '.join(p)
        subprocess.check_output(p)
# !ls ../catalog-testset/SD/SD00200000003/
copyTo('../catalog-gt/SD/', '../catalog-evaluation/', '*/*.gt.txt',ext='.gt.txt')
copyTo('../tesseract-result-dict2/', '../catalog-evaluation/', '*/*.txt', listdir(join('../catalog-gt/','SD')))
# Out:
# None
# cp ../catalog-gt/SD/SD00200000245/010002.gt.txt ../catalog-evaluation/SD00200000245/010002.gt.txt
# cp ../catalog-gt/SD/SD00200000245/010001.gt.txt ../catalog-evaluation/SD00200000245/010001.gt.txt
# cp ../catalog-gt/SD/SD00200000245/010004.gt.txt ../catalog-evaluation/SD00200000245/010004.gt.txt
# cp ../catalog-gt/SD/SD00200000245/010005.gt.txt ../catalog-evaluation/SD00200000245/010005.gt.txt
# cp ../catalog-gt/SD/SD00200000245/010006.gt.txt ../catalog-evaluation/SD00200000245/010006.gt.txt
# cp ../catalog-gt/SD/SD00200000245/010003.gt.txt ../catalog-evaluation/SD00200000245/010003.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010002.gt.txt ../catalog-evaluation/SD00200000003/010002.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010001.gt.txt ../catalog-evaluation/SD00200000003/010001.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010007.gt.txt ../catalog-evaluation/SD00200000003/010007.gt.txt
# cp ../catalog-gt/SD/SD00200000003/01000c.gt.txt ../catalog-evaluation/SD00200000003/01000c.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010004.gt.txt ../catalog-evaluation/SD00200000003/010004.gt.txt
# cp ../catalog-gt/SD/SD00200000003/01000b.gt.txt ../catalog-evaluation/SD00200000003/01000b.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010005.gt.txt ../catalog-evaluation/SD00200000003/010005.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010006.gt.txt ../catalog-evaluation/SD00200000003/010006.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010009.gt.txt ../catalog-evaluation/SD00200000003/010009.gt.txt
# cp ../catalog-gt/SD/SD00200000003/01000a.gt.txt ../catalog-evaluation/SD00200000003/01000a.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010003.gt.txt ../catalog-evaluation/SD00200000003/010003.gt.txt
# cp ../catalog-gt/SD/SD00200000003/010008.gt.txt ../catalog-evaluation/SD00200000003/010008.gt.txt
# cp ../catalog-gt/SD/SD00200000608/010002.gt.txt ../catalog-evaluation/SD00200000608/010002.gt.txt
# cp ../catalog-gt/SD/SD00200000608/010001.gt.txt ../catalog-evaluation/SD00200000608/010001.gt.txt
# cp ../catalog-gt/SD/SD00200000608/010003.gt.txt ../catalog-evaluation/SD00200000608/010003.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010002.gt.txt ../catalog-evaluation/SD00600000258/010002.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010001.gt.txt ../catalog-evaluation/SD00600000258/010001.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010004.gt.txt ../catalog-evaluation/SD00600000258/010004.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010005.gt.txt ../catalog-evaluation/SD00600000258/010005.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010006.gt.txt ../catalog-evaluation/SD00600000258/010006.gt.txt
# cp ../catalog-gt/SD/SD00600000258/010003.gt.txt ../catalog-evaluation/SD00600000258/010003.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010002.gt.txt ../catalog-evaluation/SD00600000272/010002.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010001.gt.txt ../catalog-evaluation/SD00600000272/010001.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010007.gt.txt ../catalog-evaluation/SD00600000272/010007.gt.txt
# cp ../catalog-gt/SD/SD00600000272/01000c.gt.txt ../catalog-evaluation/SD00600000272/01000c.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010004.gt.txt ../catalog-evaluation/SD00600000272/010004.gt.txt
# cp ../catalog-gt/SD/SD00600000272/01000b.gt.txt ../catalog-evaluation/SD00600000272/01000b.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010005.gt.txt ../catalog-evaluation/SD00600000272/010005.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010006.gt.txt ../catalog-evaluation/SD00600000272/010006.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010009.gt.txt ../catalog-evaluation/SD00600000272/010009.gt.txt
# cp ../catalog-gt/SD/SD00600000272/01000a.gt.txt ../catalog-evaluation/SD00600000272/01000a.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010003.gt.txt ../catalog-evaluation/SD00600000272/010003.gt.txt
# cp ../catalog-gt/SD/SD00600000272/010008.gt.txt ../catalog-evaluation/SD00600000272/010008.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010002.gt.txt ../catalog-evaluation/SD01200000085/010002.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010001.gt.txt ../catalog-evaluation/SD01200000085/010001.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010004.gt.txt ../catalog-evaluation/SD01200000085/010004.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010005.gt.txt ../catalog-evaluation/SD01200000085/010005.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010006.gt.txt ../catalog-evaluation/SD01200000085/010006.gt.txt
# cp ../catalog-gt/SD/SD01200000085/010003.gt.txt ../catalog-evaluation/SD01200000085/010003.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010002.gt.txt ../catalog-evaluation/SD00600000535/010002.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010001.gt.txt ../catalog-evaluation/SD00600000535/010001.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010007.gt.txt ../catalog-evaluation/SD00600000535/010007.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010004.gt.txt ../catalog-evaluation/SD00600000535/010004.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010005.gt.txt ../catalog-evaluation/SD00600000535/010005.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010006.gt.txt ../catalog-evaluation/SD00600000535/010006.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010009.gt.txt ../catalog-evaluation/SD00600000535/010009.gt.txt
# cp ../catalog-gt/SD/SD00600000535/01000a.gt.txt ../catalog-evaluation/SD00600000535/01000a.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010003.gt.txt ../catalog-evaluation/SD00600000535/010003.gt.txt
# cp ../catalog-gt/SD/SD00600000535/010008.gt.txt ../catalog-evaluation/SD00600000535/010008.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010002.gt.txt ../catalog-evaluation/SD00600000323/010002.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010001.gt.txt ../catalog-evaluation/SD00600000323/010001.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010007.gt.txt ../catalog-evaluation/SD00600000323/010007.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010004.gt.txt ../catalog-evaluation/SD00600000323/010004.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010005.gt.txt ../catalog-evaluation/SD00600000323/010005.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010006.gt.txt ../catalog-evaluation/SD00600000323/010006.gt.txt
# cp ../catalog-gt/SD/SD00600000323/010003.gt.txt ../catalog-evaluation/SD00600000323/010003.gt.txt
# ['SD00200000245', 'SD00200000003', 'SD00200000608', 'SD00600000258', 'SD00600000272', 'SD01200000085', 'SD00600000535', 'SD00600000323']
# cp ../tesseract-result-dict2/SD00200000245/010002.txt.txt ../catalog-evaluation/SD00200000245/010002.txt
# cp ../tesseract-result-dict2/SD00200000245/010001.txt.txt ../catalog-evaluation/SD00200000245/010001.txt
# cp ../tesseract-result-dict2/SD00200000245/010003.txt.txt ../catalog-evaluation/SD00200000245/010003.txt
# cp ../tesseract-result-dict2/SD00200000245/010006.txt.txt ../catalog-evaluation/SD00200000245/010006.txt
# cp ../tesseract-result-dict2/SD00200000245/010004.txt.txt ../catalog-evaluation/SD00200000245/010004.txt
# cp ../tesseract-result-dict2/SD00200000245/010005.txt.txt ../catalog-evaluation/SD00200000245/010005.txt
# cp ../tesseract-result-dict2/SD00200000003/01000a.txt.txt ../catalog-evaluation/SD00200000003/01000a.txt
# cp ../tesseract-result-dict2/SD00200000003/010007.txt.txt ../catalog-evaluation/SD00200000003/010007.txt
# cp ../tesseract-result-dict2/SD00200000003/010002.txt.txt ../catalog-evaluation/SD00200000003/010002.txt
# cp ../tesseract-result-dict2/SD00200000003/010001.txt.txt ../catalog-evaluation/SD00200000003/010001.txt
# cp ../tesseract-result-dict2/SD00200000003/010003.txt.txt ../catalog-evaluation/SD00200000003/010003.txt
# cp ../tesseract-result-dict2/SD00200000003/010009.txt.txt ../catalog-evaluation/SD00200000003/010009.txt
# cp ../tesseract-result-dict2/SD00200000003/010006.txt.txt ../catalog-evaluation/SD00200000003/010006.txt
# cp ../tesseract-result-dict2/SD00200000003/01000b.txt.txt ../catalog-evaluation/SD00200000003/01000b.txt
# cp ../tesseract-result-dict2/SD00200000003/010004.txt.txt ../catalog-evaluation/SD00200000003/010004.txt
# cp ../tesseract-result-dict2/SD00200000003/010008.txt.txt ../catalog-evaluation/SD00200000003/010008.txt
# cp ../tesseract-result-dict2/SD00200000003/01000c.txt.txt ../catalog-evaluation/SD00200000003/01000c.txt
# cp ../tesseract-result-dict2/SD00200000003/010005.txt.txt ../catalog-evaluation/SD00200000003/010005.txt
# cp ../tesseract-result-dict2/SD00200000608/010002.txt.txt ../catalog-evaluation/SD00200000608/010002.txt
# cp ../tesseract-result-dict2/SD00200000608/010001.txt.txt ../catalog-evaluation/SD00200000608/010001.txt
# cp ../tesseract-result-dict2/SD00200000608/010003.txt.txt ../catalog-evaluation/SD00200000608/010003.txt
# cp ../tesseract-result-dict2/SD00600000258/010002.txt.txt ../catalog-evaluation/SD00600000258/010002.txt
# cp ../tesseract-result-dict2/SD00600000258/010001.txt.txt ../catalog-evaluation/SD00600000258/010001.txt
# cp ../tesseract-result-dict2/SD00600000258/010003.txt.txt ../catalog-evaluation/SD00600000258/010003.txt
# cp ../tesseract-result-dict2/SD00600000258/010006.txt.txt ../catalog-evaluation/SD00600000258/010006.txt
# cp ../tesseract-result-dict2/SD00600000258/010004.txt.txt ../catalog-evaluation/SD00600000258/010004.txt
# cp ../tesseract-result-dict2/SD00600000258/010005.txt.txt ../catalog-evaluation/SD00600000258/010005.txt
# cp ../tesseract-result-dict2/SD00600000272/01000a.txt.txt ../catalog-evaluation/SD00600000272/01000a.txt
# cp ../tesseract-result-dict2/SD00600000272/010007.txt.txt ../catalog-evaluation/SD00600000272/010007.txt
# cp ../tesseract-result-dict2/SD00600000272/010002.txt.txt ../catalog-evaluation/SD00600000272/010002.txt
# cp ../tesseract-result-dict2/SD00600000272/010001.txt.txt ../catalog-evaluation/SD00600000272/010001.txt
# cp ../tesseract-result-dict2/SD00600000272/010003.txt.txt ../catalog-evaluation/SD00600000272/010003.txt
# cp ../tesseract-result-dict2/SD00600000272/010009.txt.txt ../catalog-evaluation/SD00600000272/010009.txt
# cp ../tesseract-result-dict2/SD00600000272/010006.txt.txt ../catalog-evaluation/SD00600000272/010006.txt
# cp ../tesseract-result-dict2/SD00600000272/01000b.txt.txt ../catalog-evaluation/SD00600000272/01000b.txt
# cp ../tesseract-result-dict2/SD00600000272/010004.txt.txt ../catalog-evaluation/SD00600000272/010004.txt
# cp ../tesseract-result-dict2/SD00600000272/010008.txt.txt ../catalog-evaluation/SD00600000272/010008.txt
# cp ../tesseract-result-dict2/SD00600000272/01000c.txt.txt ../catalog-evaluation/SD00600000272/01000c.txt
# cp ../tesseract-result-dict2/SD00600000272/010005.txt.txt ../catalog-evaluation/SD00600000272/010005.txt
# cp ../tesseract-result-dict2/SD01200000085/010002.txt.txt ../catalog-evaluation/SD01200000085/010002.txt
# cp ../tesseract-result-dict2/SD01200000085/010001.txt.txt ../catalog-evaluation/SD01200000085/010001.txt
# cp ../tesseract-result-dict2/SD01200000085/010003.txt.txt ../catalog-evaluation/SD01200000085/010003.txt
# cp ../tesseract-result-dict2/SD01200000085/010006.txt.txt ../catalog-evaluation/SD01200000085/010006.txt
# cp ../tesseract-result-dict2/SD01200000085/010004.txt.txt ../catalog-evaluation/SD01200000085/010004.txt
# cp ../tesseract-result-dict2/SD01200000085/010005.txt.txt ../catalog-evaluation/SD01200000085/010005.txt
# cp ../tesseract-result-dict2/SD00600000535/01000a.txt.txt ../catalog-evaluation/SD00600000535/01000a.txt
# cp ../tesseract-result-dict2/SD00600000535/010007.txt.txt ../catalog-evaluation/SD00600000535/010007.txt
# cp ../tesseract-result-dict2/SD00600000535/010002.txt.txt ../catalog-evaluation/SD00600000535/010002.txt
# cp ../tesseract-result-dict2/SD00600000535/010001.txt.txt ../catalog-evaluation/SD00600000535/010001.txt
# cp ../tesseract-result-dict2/SD00600000535/010003.txt.txt ../catalog-evaluation/SD00600000535/010003.txt
# cp ../tesseract-result-dict2/SD00600000535/010009.txt.txt ../catalog-evaluation/SD00600000535/010009.txt
# cp ../tesseract-result-dict2/SD00600000535/010006.txt.txt ../catalog-evaluation/SD00600000535/010006.txt
# cp ../tesseract-result-dict2/SD00600000535/010004.txt.txt ../catalog-evaluation/SD00600000535/010004.txt
# cp ../tesseract-result-dict2/SD00600000535/010008.txt.txt ../catalog-evaluation/SD00600000535/010008.txt
# cp ../tesseract-result-dict2/SD00600000535/010005.txt.txt ../catalog-evaluation/SD00600000535/010005.txt
# cp ../tesseract-result-dict2/SD00600000323/010007.txt.txt ../catalog-evaluation/SD00600000323/010007.txt
# cp ../tesseract-result-dict2/SD00600000323/010002.txt.txt ../catalog-evaluation/SD00600000323/010002.txt
# cp ../tesseract-result-dict2/SD00600000323/010001.txt.txt ../catalog-evaluation/SD00600000323/010001.txt
# cp ../tesseract-result-dict2/SD00600000323/010003.txt.txt ../catalog-evaluation/SD00600000323/010003.txt
# cp ../tesseract-result-dict2/SD00600000323/010006.txt.txt ../catalog-evaluation/SD00600000323/010006.txt
# cp ../tesseract-result-dict2/SD00600000323/010004.txt.txt ../catalog-evaluation/SD00600000323/010004.txt
# cp ../tesseract-result-dict2/SD00600000323/010005.txt.txt ../catalog-evaluation/SD00600000323/010005.txt

# %%
id_filter= listdir(join(base,'SD'))
f = '../catalog-gt/SD/SD00200000245/010006.gt.txt'
f
# Out:
# '../catalog-gt/SD/SD00200000245/010006.gt.txt'

# %%
join(base,'SD/*/*.txt')
# Out:
# '../catalog-gt/SD/*/*.txt'

# %%
# !ocropus-rpred -Q 7 -m ../ocropy/models/en-default.pyrnn.gz '../catalog-testset/SD/SD00200000003/??????.bin.png'
# Out:
# INFO:
# INFO:  ########## /home/jakob/anaconda/bin/ocropus-rpred -Q 7 -m ../ocropy/mod
# INFO:
# INFO:  #inputs13
# # loading object ../ocropy/models/en-default.pyrnn.gz
# INFO:  ../catalog-testset/SD/SD00200000003/010004.bin.png:Edition Bartbarossa.
# INFO:  ../catalog-testset/SD/SD00200000003/010005.bin.png:Vol. 4, - [1996]. - 1 Compact Disc Beih.
# INFO:  ../catalog-testset/SD/SD00200000003/010003.bin.png:8393 : Hit-Raritäten aus dem DOR-Rundfunkarchiv. - Berlin :
# INFO:  ../catalog-testset/SD/SD00200000003/010007.bin.png:Hoffnung. Fort für einen Abend. Welt im Sand. Weisst du noch.
# INFO:  ../catalog-testset/SD/SD00200000003/010006.bin.png:Enth.: Jagd auf Liebe. Steigen Netxel. u Fuss. Tshgiten-Legende.
# INFO:  ../catalog-testset/SD/SD00200000003/010001.bin.png:Babylon
# INFO:  ../catalog-testset/SD/SD00200000003/010002.bin.png:55 CD 289 - 4
# ERROR:  ../catalog-testset/SD/SD00200000003/01000d.bin.png SKIPPED line too short (28, 36) (use -n to disable this check)
# INFO:  ../catalog-testset/SD/SD00200000003/01000b.bin.png:weiterführen.
# INFO:  ../catalog-testset/SD/SD00200000003/01000c.bin.png:Interbr . 8osalili. Lift. %g ress. Keks. Punays, Karat.
# INFO:  ../catalog-testset/SD/SD00200000003/01000a.bin.png:EIn Agentlick der ZSrtlchkeit. Das Bild. Strassen, die dich
# INFO:  ../catalog-testset/SD/SD00200000003/010009.bin.png:d1e Weide. Einmal unsichtbar sein. Schwester. He1sses Land.
# INFO:  ../catalog-testset/SD/SD00200000003/010008.bin.png:Wir gehn zu mir. Der Morgen auf dem Gipfel. Aus dem Al1. Am Fluss

# %%
# !ocropus-errs  '../catalog-evaluation/*/??????.gt.txt'
# Out:
#      0	     7	../catalog-evaluation/SD00200000003/010001.gt.txt
#      0	    13	../catalog-evaluation/SD00200000003/010002.gt.txt
#      1	    64	../catalog-evaluation/SD00200000003/010003.gt.txt
#      1	    19	../catalog-evaluation/SD00200000003/010004.gt.txt
#      2	    42	../catalog-evaluation/SD00200000003/010005.gt.txt
#      6	    63	../catalog-evaluation/SD00200000003/010006.gt.txt
#      4	    61	../catalog-evaluation/SD00200000003/010007.gt.txt
#      1	    65	../catalog-evaluation/SD00200000003/010008.gt.txt
#      5	    59	../catalog-evaluation/SD00200000003/010009.gt.txt
#      7	    61	../catalog-evaluation/SD00200000003/01000a.gt.txt
#      4	    13	../catalog-evaluation/SD00200000003/01000b.gt.txt
#     11	    54	../catalog-evaluation/SD00200000003/01000c.gt.txt
#      2	    37	../catalog-evaluation/SD00200000245/010001.gt.txt
#      6	    37	../catalog-evaluation/SD00200000245/010002.gt.txt
#      2	     6	../catalog-evaluation/SD00200000245/010003.gt.txt
#      6	    26	../catalog-evaluation/SD00200000245/010004.gt.txt
#      1	    12	../catalog-evaluation/SD00200000245/010005.gt.txt
#      0	    15	../catalog-evaluation/SD00200000245/010006.gt.txt
#      4	    30	../catalog-evaluation/SD00200000608/010001.gt.txt
#      0	     5	../catalog-evaluation/SD00200000608/010002.gt.txt
#      4	    35	../catalog-evaluation/SD00200000608/010003.gt.txt
#      2	    40	../catalog-evaluation/SD00600000258/010001.gt.txt
#      0	    10	../catalog-evaluation/SD00600000258/010002.gt.txt
#      1	    42	../catalog-evaluation/SD00600000258/010003.gt.txt
#      3	    39	../catalog-evaluation/SD00600000258/010004.gt.txt
#      3	    42	../catalog-evaluation/SD00600000258/010005.gt.txt
#      2	    12	../catalog-evaluation/SD00600000258/010006.gt.txt
#      1	    46	../catalog-evaluation/SD00600000272/010001.gt.txt
#      6	    23	../catalog-evaluation/SD00600000272/010002.gt.txt
#      3	    53	../catalog-evaluation/SD00600000272/010003.gt.txt
#      3	    76	../catalog-evaluation/SD00600000272/010004.gt.txt
#      4	    69	../catalog-evaluation/SD00600000272/010005.gt.txt
#      3	    49	../catalog-evaluation/SD00600000272/010006.gt.txt
#      2	    70	../catalog-evaluation/SD00600000272/010007.gt.txt
#      4	    65	../catalog-evaluation/SD00600000272/010008.gt.txt
#      1	    52	../catalog-evaluation/SD00600000272/010009.gt.txt
#      2	    69	../catalog-evaluation/SD00600000272/01000a.gt.txt
#      0	    39	../catalog-evaluation/SD00600000272/01000b.gt.txt
#      4	    18	../catalog-evaluation/SD00600000272/01000c.gt.txt
#      0	     5	../catalog-evaluation/SD00600000323/010001.gt.txt
#      8	    58	../catalog-evaluation/SD00600000323/010002.gt.txt
#      6	    53	../catalog-evaluation/SD00600000323/010003.gt.txt
#      2	    26	../catalog-evaluation/SD00600000323/010004.gt.txt
#      2	    61	../catalog-evaluation/SD00600000323/010005.gt.txt
#      1	    58	../catalog-evaluation/SD00600000323/010006.gt.txt
#      1	     8	../catalog-evaluation/SD00600000323/010007.gt.txt
#      3	    21	../catalog-evaluation/SD00600000535/010001.gt.txt
#      0	    23	../catalog-evaluation/SD00600000535/010002.gt.txt
#      0	     6	../catalog-evaluation/SD00600000535/010003.gt.txt
#      7	    59	../catalog-evaluation/SD00600000535/010004.gt.txt
#     11	    60	../catalog-evaluation/SD00600000535/010005.gt.txt
#      8	    62	../catalog-evaluation/SD00600000535/010006.gt.txt
#      2	    62	../catalog-evaluation/SD00600000535/010007.gt.txt
#      5	    62	../catalog-evaluation/SD00600000535/010008.gt.txt
#      3	    60	../catalog-evaluation/SD00600000535/010009.gt.txt
#     10	    62	../catalog-evaluation/SD00600000535/01000a.gt.txt
#      2	    28	../catalog-evaluation/SD01200000085/010001.gt.txt
#      0	    15	../catalog-evaluation/SD01200000085/010002.gt.txt
#      5	    45	../catalog-evaluation/SD01200000085/010003.gt.txt
#      0	     7	../catalog-evaluation/SD01200000085/010004.gt.txt
#      3	    31	../catalog-evaluation/SD01200000085/010005.gt.txt
#      2	    47	../catalog-evaluation/SD01200000085/010006.gt.txt
# errors         192
# missing          0
# total         2457
# err          7.814 %
# errnomiss    7.814 %

# %%
# !ocropus-econf '../catalog-evaluation/*/??????.gt.txt'
# Out:
# errors         192
# missing          0
# total         2457
# err          7.814 %
# errnomiss    7.814 %
# 11	l	i
# 4	3	J
# 4	_
# 4	 	_
# 3	_	.
# 3	é	á
# 3	.	_
# 2	 	g
# 2	c	e
# 2	m_	in
# 0.0781440781441

# %%
# %%capture output
import datetime as dt
before = dt.datetime.now()

# !ocropus-nlbin -t 0.5 -z 1.0 ../catalog-testset/SD???????????.png
# !ocropus-gpageseg --maxcolseps 0 --usegauss -z 1.0 ../catalog-testset/SD???????????.bin.png
# !ocropus-rpred -q -Q 7 -m ../ocropy/models/en-default.pyrnn.gz '../catalog-testset/SD???????????/??????.bin.png'

delta = dt.datetime.now() - before
delta.total_seconds()
# Out:
# 971.727955

# %%
print str(delta / len(glob('../catalog-testset/SD???????????.png')))
print str(delta / len(glob('../catalog-testset/SD???????????.png')) * 1000000)
# Out:
# 0:00:04.858639
# 56 days, 5:37:19

# %%
str(delta / 200)
# Out:
# '0:00:04.858639'
