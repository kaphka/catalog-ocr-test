# %%
import ujson
from glob import glob
import os.path as op

# %%
def split_index_path(path):
    splitted = op.normpath(path).split(op.sep)
    ifile = splitted[-1]
    cat_name = splitted[-2]
    return cat_name, path

# %%
def read_catalog_db(data, split_char='\t'):
    field_seperator = '\x00'
    fields  = [field.split(field_seperator) for field in data.split(split_char)]
    entries = [field for field in fields if field[3] == bytes('d')]
    index   = {entry[0].decode('utf8'): entry[4].decode('utf8')[1:] for entry in entries}
    return index

# %%
def export_index_to_json(cat_name, dat_path):
    json_path = '/media/jakob/bigdata/index_data/{}_indicies.json'.format(cat_name)
    with open(dat_path, 'rb') as f:
        data = bytearray(f.read())
        if cat_name == 'S':
            index = read_catalog_db(data, split_char='\x08')
        else:
            index = read_catalog_db(data)
            
    with open(json_path, 'wb') as out:
        print(json_path)
        json_data = {'name': cat_name, 'index': index}
        ujson.dump(json_data,out,indent=4,ensure_ascii=False)

# %%
paths = glob('/media/jakob/bigdata/repository.org.20091214/catalogs/*/data*.dat')
data_files = {cat_name: path for cat_name, path in map(split_index_path, paths)}
sorted(data_files.keys())
# Out:
# ['S', 'SB', 'SC', 'SD', 'SE']

# %%
for data in data_files.items():
    export_index_to_json(*data)
# Out:
# /media/jakob/bigdata/index_data/SC_indicies.json
# /media/jakob/bigdata/index_data/SB_indicies.json
# /media/jakob/bigdata/index_data/S_indicies.json
# /media/jakob/bigdata/index_data/SE_indicies.json
# /media/jakob/bigdata/index_data/SD_indicies.json

# %%
# !cat /media/jakob/bigdata/index_data/SD_indicies.json
# Out:
# {
#     "index":{
#         "SD0150421":"Rundfunk-Sinfonieorchester <Leipzig>",
#         "SD0160065":"Salzburger Bachchor",
#         "SD0120200":"Orchestra Internazionale d'Italia",
#         "SD0060525":"Gürzenich-Orchester <Köln>",
#         "SD0080061":"Kammerorchester C. Ph. E. Bach <Berlin, Ost>",
#         "SD0070055":"Hamburgische Staatsoper \/ Chor",
#         "SD0140104":"Radio-Sinfonie-Orchester <Frankfurt, Main>",
#         "SD0020221":"Bayerische Staatsoper <München> \/ Chor",
#         "SD0150189":"Rundfunk im Amerikanischen Sektor Berlins \/ Kammerensemble",
#         "SD0130364":"Philharmonisches Staatsorchester <Hamburg>",
#         "SD0160819":"Studio for New Music",
#         "SD0100002":"Ma'alot-Quintett",
#         "SD0110250":"New Budapest Quartet",
#         "SD0130570":"Prazský Komorní Sbor",
#         "SD0040423":"Coro Gulbenkian <Lisboa>",
#         "SD0020736":"British Broadcasting Corporation <London> \/ Symphony Orchestra",
#         "SD0050419":"Ensemble <Köln>",
#         "SD0140142":"Radio-Sinfonieorchester <Stuttgart>",
#         "SD0060467":"Großes Funkorchester <Berlin>",
#         "SD0090158":"London Philharmonic Orchestra",
#         "SD0150452":"Rundfunk-Sinfonieorchester <Saarbrücken>",
#         "SD0090228":"London Symphony Chorus",
#         "SD0060287":"Gewandhausorchester <Leipzig>",
#         "SD0170457":"Thüringer Landestheater <Rudolstadt> \/ Chor",
#         "SD0040099":"Columbia Chorus",
#         "SD0050002":"Da Camera e da Chiesa",
#         "SD0120400":"Orphénica Lyra",
#         "SD0050555":"Ensemble Modern",
#         "SD0110455":"Nordwestdeutsche Philharmonie <Herford>",
#         "SD0160770":"Stavanger Symphony Orchestra",
#         "SD0100277":"Monteverdi-Chor <Hamburg>",
#         "SD0040092":"Columbia Chamber Orchestra",
#         "SD0060082":"Filharmonisk Selskap <Oslo> \/ Orkester",
#         "SD0020782":"British Broadcasting Corporation <London> \/ Theatre Chorus",
#         "SD0130647":"Quadri",
#         "SD0030579":"Clemencic-Consort <Wien>",
#         "SD0080152":"Karl Richter und Sein Kammerorchester",
#         "SD0010202":"Alfons und Aloys Kontarsky",
#         "SD0140174":"Radiosymfoniorkestret <Kobenhavn>",
#         "SD0160078":"Salzburger Kammerchor",
#         "SD0140360":"Reform",
#         "SD0070105":"Hawthorne String Quartet",
#         "SD0120350":"Orchestre Révolutionnaire et Romantique <London>",
#         "SD0150270":"Rundfunkchor <Leipzig>",
#         "SD0110150":"National Philharmonic Orchestra <London>",
#         "SD0170591":"Trio Ensemble Recherche",
#         "SD0030002":"Cabaza Percussion Quartet",
#         "SD0150141":"Rundfunk im Amerikanischen Sektor Berlins \/ Kammerchor",
#         "SD0020257":"Bayreuther Festspiele \/ Chor",
#         "SD0060238":"Geidai Philharmonia Orchestra <Tokyo>",
#         "SD0080419":"Koninklijk Filharmonisch Orkest van Vlaanderen <Anvers>",
#         "SD0060132":"Frankfurter Kantorei",
#         "SD0020546":"Berliner Solisten",
#         "SD0090339":"London Voices",
#         "SD0170400":"Théâtre de l'Opéra <Lyon> \/ Choeurs",
#         "SD0070187":"Hilliard Ensemble",
#         "SD0110417":"Norddeutscher Rundfunk <Hamburg> \/ Sinfonieorchester",
#         "SD0090239":"London Symphony Orchestra: Arnold",
#         "SD0050020":"Danubius String Quartet",
#         "SD0170299":"Teatro alla Scala <Milano> \/ Orchestra",
#         "SD0180002":"Új Budapest Vonósnégyes",
#         "SD0110199":"Nederlands Kamerkoor <Amsterdam>",
#         "SD0130033":"Panstwowa Filharmonia Slaska <Katowice> \/ Chór",
#         "SD0050705":"Estonian Philharmonic Chamber Choir",
#         "SD0110392":"Norddeutscher Rundfunk <Hamburg> \/ Chor",
#         "SD0160303":"Slagwerkgroep <'s-Gravenhage>",
#         "SD0040323":"Consort of Musicke",
#         "SD0090002":"Labia Vocalia <Berlin>",
#         "SD0050605":"Ensemble Sechsundsiebzig <Stuttgart>",
#         "SD0160594":"Staatsoper <Wien> \/ Orchester",
#         "SD0170491":"Tölzer Knabenchor",
#         "SD0110002":"Nacional'nyj Zasluzenyj Akademicnyj Orkestr Ukrainy <Kyiv>",
#         "SD0150089":"Royal Philharmonic Orchestra <London>",
#         "SD0010356":"Arditti String Quartet",
#         "SD0180224":"Wiener Philharmoniker: Bach",
#         "SD0020651":"Brahms-Quartett",
#         "SD0100410":"Münchner Philharmoniker",
#         "SD0140002":"Radio Corporation of America <New York, NY> \/ Italiana Division \/ Chorus",
#         "SD0110088":"National Broadcasting Company <New York, NY> \/ Symphony Orchestra: Mendelssohn",
#         "SD0110278":"New Philharmonia Orchestra <London>",
#         "SD0080489":"Kühnuv Smísený Sbor <Praha>",
#         "SD0140314":"Radiotelevisione Italiana <Roma> \/ Coro <Roma>",
#         "SD0020499":"Berliner Philharmoniker: Wilhelm",
#         "SD0080085":"Kammerorchester Convivium Musicum <München>",
#         "SD0120052":"Oktoberklub",
#         "SD0120299":"Orchestre National <Monte Carlo>",
#         "SD0100493":"Musica Antiqua <Köln>",
#         "SD0140082":"Radio-Philharmonie <Hannover>",
#         "SD0030484":"Choralschola der Benediktinerabtei Königsmünster <Meschede>",
#         "SD0050470":"Ensemble Braccio",
#         "SD0050111":"Deutsche Staatsoper <Berlin> \/ Chor",
#         "SD0050261":"Duo Rossiniane",
#         "SD0030240":"Ceská Filharmonie <Praha>: Schönberg",
#         "SD0130182":"Philharmonia Orchestra <London>: Beethoven",
#         "SD0130332":"Philharmonisches Oktett <Berlin, West>",
#         "SD0090153":"London Philharmonic Choir",
#         "SD0130027":"Panstwowa Filharmonia Slaska <Katowice>",
#         "SD0180423":"Württembergisches Staatsorchester <Stuttgart>",
#         "SD0170348":"Teatro Massimo <Palermo> \/ Orchestra",
#         "SD0130232":"Philharmonia Orchestra <London>: Meyerbeer",
#         "SD0100232":"Monteverdi Choir <London>",
#         "SD0040011":"Collegium Aureum <Köln>",
#         "SD0140428":"Rheinische Kantorei <Köln>",
#         "SD0060417":"Gosudarstvennyj Simfoniceskij Orkestr SSSR <Moskva>",
#         "SD0020002":"Babylon",
#         "SD0100543":"Musicae Antiquae Collegium Varsoviense",
#         "SD0010502":"Auryn-Quartett",
#         "SD0110031":"National Broadcasting Company <New York, NY> \/ Chorus",
#         "SD0180323":"Wiener Singakademie",
#         "SD0170272":"Teatro alla Scala <Milano> \/ Coro",
#         "SD0140294":"Radio-Télévision Belge de la Communauté Culturelle Française <Bruxelles> \/ Nouvel Orchestre Symphonique",
#         "SD0110330":"New York Philharmonic",
#         "SD0160091":"Salzburger Rundfunk- und Mozarteumchor",
#         "SD0030385":"Choeurs de la Radio d'URSS",
#         "SD0020372":"Berliner Barock-Compagney",
#         "SD0160319":"Slovenská Filharmónia <Bratislava>",
#         "SD0030146":"Cappella Coloniensis",
#         "SD0160290":"Sixteen <London>",
#         "SD0050285":"Dvorákuv Komorní Orchestr <Praha>",
#         "SD0020272":"Bayreuther Festspiele \/ Orchester",
#         "SD0080333":"Kölner Rundfunkorchester",
#         "SD0020402":"Berliner Philharmoniker: Aufforderung",
#         "SD0010050":"Academy of Saint Martin-in-the-Fields <London>: Britten",
#         "SD0010298":"American Moravian Chamber Orchestra",
#         "SD0180079":"Virtuosi Saxoniae <Dresden>",
#         "SD0040102":"Columbia Jazz Ensemble",
#         "SD0090224":"London Sinfonietta Chorus",
#         "SD0040107":"Columbia Percussion Ensemble",
#         "SD0150364":"Rundfunk-Sinfonieorchester <Berlin, Ost>",
#         "SD0120100":"Opera Society <Washington, DC> \/ Orchestra",
#         "SD0180345":"Wiener Symphoniker",
#         "SD0110441":"Norddeutscher Singkreis <Hamburg>",
#         "SD0160190":"Scottish Chamber Orchestra <Edinburgh>",
#         "SD0070002":"Händel-Collegium <Köln>",
#         "SD0170219":"Tafelmusik",
#         "SD0060318":"Göbel-Trio",
#         "SD0160556":"Staatsoper <Wien> \/ Chor",
#         "SD0050370":"English Chamber Orchestra <London>",
#         "SD0040224":"Concert Spirituel",
#         "SD0100221":"Mitteldeutscher Rundfunk <Leipzig> \/ Kinderchor",
#         "SD0050211":"Dresdner Philharmonie",
#         "SD0130619":"Pro Musica <Köln>",
#         "SD0070155":"Helsingin Kaupunginorkesteri",
#         "SD0060080":"Filharmonisk Selskap <Oslo> \/ Kor",
#         "SD0020171":"Bayerische Rundfunk <München> \/ Symphonieorchester",
#         "SD0050100":"Deutsche Oper <Berlin, West> \/ Orchester",
#         "SD0080028":"Kammerchor <Stuttgart>",
#         "SD0130282":"Philharmonia-Chor <Stuttgart>",
#         "SD0130083":"Pécs Symphony Orchestra",
#         "SD0100171":"Melbourne Symphony Orchestra",
#         "SD0050299":"Early Music Consort <London>",
#         "SD0020075":"Bamberger Symphoniker",
#         "SD0080102":"Kammerorchester Musica Bavarica <München>",
#         "SD0140317":"Radiotelevisione Italiana <Roma> \/ Coro <Torino>",
#         "SD0100121":"Mariinskij Teatr <Sankt-Petersburg> \/ Chor",
#         "SD0180126":"Wallace Collection",
#         "SD0140335":"Radiotelevisione Italiana <Roma> \/ Orchestra Sinfonica <Torino>",
#         "SD0160241":"Sinfonieorchester <Basel>",
#         "SD0140331":"Radiotelevisione Italiana <Roma> \/ Orchestra Sinfonica <Roma>",
#         "SD0170041":"Südwestdeutsches Kammerorchester <Pforzheim>",
#         "SD0060368":"Gosudarstvennyj Akademiceskij Bol'soj Teatr SSSR <Moskva> \/ Orkestr",
#         "SD0060002":"Fanny Mendelssohn Quartett",
#         "SD0060004":"Fanny-Mendelssohn-Quartett: Bacewicz",
#         "SD0180273":"Wiener Philharmoniker: Mozart",
#         "SD0080220":"Kleine Konzert",
#         "SD0150051":"Royal Albert Hall Orchestra <London>",
#         "SD0180048":"Van Gendt Quintet",
#         "SD0140402":"Rheinische Kantorei <Dormagen>",
#         "SD0110505":"Norwegian Chamber Orchestra",
#         "SD0040111":"Columbia Symphony Orchestra",
#         "SD0010100":"Academy of Saint Martin-in-the-Fields <London>: Walton",
#         "SD0140307":"Radiotelevisione Italiana <Roma> \/ Coro <Milano>",
#         "SD0150078":"Royal Opera House Covent Garden <London> \/ Orchestra",
#         "SD0160644":"Stadtmusik <Wien>",
#         "SD0180446":"Zagrebacki Solisti",
#         "SD0180441":"",
#         "SD0130592":"Preussische Staatskapelle <Berlin>",
#         "SD0070365":"John Alldis Choir <London>",
#         "SD0050366":"English Chamber Choir <London>",
#         "SD0160051":"Saint Louis Symphony Orchestra",
#         "SD0010452":"Arts Florissants",
#         "SD0170165":"Symfonický Orchestr Hlavního Mesta Prahy FOK",
#         "SD0100351":"Mozarteum-Orchester <Salzburg>",
#         "SD0010248":"Ambrosian Opera Chorus <London>",
#         "SD0120094":"Opera Society <Washington, DC> \/ Chorus",
#         "SD0080295":"Kölner Rundfunkchor",
#         "SD0010392":"Arnold-Schönberg-Chor <Wien>",
#         "SD0160487":"Staatskapelle <Berlin, Ost>",
#         "SD0080002":"Kameren Ansambâl Filipopolis <Plovdiv>",
#         "SD0120250":"Orchestre <Paris>",
#         "SD0140033":"Radiokoret <Kobenhavn>",
#         "SD0030434":"Chor der Sankt-Hedwigs-Kathedrale <Berlin, West>",
#         "SD0090288":"London Symphony Orchestra: Mozart",
#         "SD0180436":"Xenakis Ensemble <Amsterdam>",
#         "SD0140322":"Radiotelevisione Italiana <Roma> \/ Orchestra Sinfonica <Milano>",
#         "SD0030534":"City of Birmingham Symphony Orchestra",
#         "SD0100052":"Mahler Chamber Orchestra",
#         "SD0070335":"J. Rosamond Johnson Chorus",
#         "SD0080523":"Kwartet Wilanowski",
#         "SD0150064":"Royal Opera House Covent Garden <London> \/ Chorus",
#         "SD0170405":"Théâtre de l'Opéra <Lyon> \/ Maîtrise",
#         "SD0160141":"Schola Cantorum <Stuttgart>",
#         "SD0050506":"Ensemble Dreizehn <Baden-Baden>",
#         "SD0150345":"Rundfunk-Kinderchor <Berlin, Ost>",
#         "SD0080459":"Kronos String Quartet",
#         "SD0140245":"Radio-Symphonie-Orchester <Berlin, West>: Mendelssohn",
#         "SD0170408":"Théatre de l'Opéra <Lyon> \/ Orchestre",
#         "SD0100273":"Monteverdi Orchestra <London>",
#         "SD0050059":"Deutsche Kammerakademie <Neuss>",
#         "SD0100326":"Moskovskij Kamernyj Orkestr",
#         "SD0120002":"Octeto Vocal Juan D. Tercero",
#         "SD0030335":"Chicago Symphony Orchestra",
#         "SD0160435":"Sonare-Quartett",
#         "SD0040160":"Compagnie Luxembourgeoise de Télédiffusion \/ Orchestre Symphonique",
#         "SD0160349":"Slovenský Rozhlas <Bratislava> \/ Symfonický Orchester",
#         "SD0060184":"Gabrieli Consort and Players <London>",
#         "SD0180399":"Württembergisches Kammerorchester <Heilbronn>",
#         "SD0100612":"Musiktheater <Bielefeld> \/ Chor",
#         "SD0160330":"Slovenská Filharmónia <Bratislava> \/ Spevcky Sbor",
#         "SD0070236":"Huelgas Ensemble",
#         "SD0180396":"Württembergischer Kammerchor <Stuttgart>",
#         "SD0110138":"National Broadcasting Company <New York, NY> \/ Symphony Orchestra: Verdi",
#         "SD0100450":"Münchner Rundfunkorchester",
#         "SD0170111":"Sukuv Komorní Orchestr <Praha>",
#         "SD0150192":"Rundfunk im Amerikanischen Sektor Berlins \/ Sinfonietta",
#         "SD0030292":"Chamber Orchestra of Europe",
#         "SD0090199":"London Sinfonietta",
#         "SD0020052":"Balgarsko Radio i Televizija <Sofija> \/ Simfonicen Orkestar",
#         "SD0150219":"Rundfunkchor <Berlin, Ost>",
#         "SD0060188":"Gächinger Kantorei <Stuttgart>",
#         "SD0020451":"Berliner Philharmoniker: Grieg",
#         "SD0020322":"Belcanto Strings",
#         "SD0100065":"Malmö Symfoni Orkester",
#         "SD0080202":"Klangforum <Wien>",
#         "SD0030055":"Canadian Broadcasting Corporation <Toronto> \/ Symphony Orchestra",
#         "SD0020698":"British Broadcasting Corporation <London> \/ Singers",
#         "SD0040078":"Columbia Chamber Ensemble",
#         "SD0130109":"Petite Bande",
#         "SD0080369":"Kölner Rundfunk-Sinfonie-Orchester",
#         "SD0170057":"Südwestfunk <Baden-Baden> \/ Sinfonieorchester",
#         "SD0180186":"Westminster Choir <Princeton, NJ>",
#         "SD0150295":"Rundfunkchor <München>",
#         "SD0090052":"Leipziger Streichquartett",
#         "SD0040373":"Consortium Classicum",
#         "SD0050344":"English Baroque Soloists",
#         "SD0040274":"Concerto Palatino",
#         "SD0150002":"Robert Shaw Chorale",
#         "SD0010152":"Akademie für Alte Musik <Berlin>",
#         "SD0160720":"Státní Filharmonie <Brno>",
#         "SD0010002":"A. A. Jurlow-Chorkapelle <Moskva>",
#         "SD0010001":"A",
#         "SD0160338":"Slovenský Komorný Orchester <Bratislava>",
#         "SD0130479":"Prazský Filharmonický Sbor Praha",
#         "SD0030329":"Chicago Symphony Chorus",
#         "SD0040174":"Concentus Musicus <Wien>",
#         "SD0020123":"Bamberger Symphoniker \/ Bläser",
#         "SD0120150":"Orchester Sankt Michael <München>",
#         "SD0130413":"",
#         "SD0130002":"Palast-Orchester",
#         "SD0110038":"National Broadcasting Company <New York, NY> \/ Symphony Orchestra: Beethoven",
#         "SD0020125":"Bamberger Symphoniker \/ Chor",
#         "SD0110380":"Nihon-hoso-kyokai <Tokyo> \/ Kokyogakudan",
#         "SD0160667":"Stagione <Frankfurt, Main>",
#         "SD0030105":"Capella Antiqua <München>",
#         "SD0150201":"Rundfunk im Amerikanischen Sektor Berlins \/ Symphonie-Orchester",
#         "SD0050656":"Ensemble Vocal Sagittarius",
#         "SD0050086":"Deutsche Oper <Berlin, West> \/ Chor",
#         "SD0130127":"Philadelphia Orchestra",
#         "SD0100563":"Musici <Roma>",
#         "SD0020602":"Blind Faith",
#         "SD0100071":"Malmö Symfoni Orkester \/ Kör",
#         "SD0080478":"Kühnuv, Detský Sbor <Praha>",
#         "SD0040060":"Collegium Vocale <Gand>",
#         "SD0160398":"Société Nationale de Radiodiffusion - Radio France <Paris> \/ Choeurs",
#         "SD0060053":"Filharmonia Narodowa <Warszawa> \/ Orkiestra Symfoniczna",
#         "SD0070280":"Ibn Báya Ensemble",
#         "SD0160471":"St. Christopher Chamber Orchestra <Vilnius>",
#         "SD0160521":"Staatskapelle <Dresden>",
#         "SD0020724":"British Broadcasting Corporation <London> \/ Symphony Chorus",
#         "SD0170013":"Südfunk-Chor <Stuttgart>",
#         "SD0110274":"New Philharmonia Chorus <London>",
#         "SD0080270":"Kocianovo Kvarteto",
#         "SD0140195":"Radio-Symphonie-Orchester <Berlin, West>: Albert",
#         "SD0030594":"Cleveland Orchestra",
#         "SD0130534":"Prazský Komorní Orchestr",
#         "SD0050161":"Deutsches Symphonie-Orchester <Berlin>",
#         "SD0130464":"Prague Chamber Orchestra",
#         "SD0160002":"Saarbrücker Streichquartett",
#         "SD0030190":"Ceská Filharmonie <Praha>: Berlioz",
#         "SD0170541":"Tommy James and the Shondells",
#         "SD0090101":"Lift",
#         "SD0050035":"Deller Consort",
#         "SD0050032":"Deller Choir",
#         "SD0130153":"Philharmonia Chorus <London>"
#     },
#     "name":"SD"
# }
